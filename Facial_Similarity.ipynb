# %%
#Importing the libraries

import numpy as np
import PIL 
from PIL import Image
import random
import torch
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader , Dataset
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.utils as vutils
import PIL.ImageOps as ImageOps
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Creating helper functions to visualize images and losses

def image_show(img , text = None ,save = False):
    ''' This Function plots the image.'''
    npimg = img.numpy()
    plt.axis("off")
    
    if text is not None: #if there is text to insert
        plt.text(75,8 , text , style= "italic" , fontweight = "bold" , bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg , (1,2,0)))
    plt.show()

def plot_loss(iteration , loss):
    plt.plot(iteration , loss)
    plt.grid(True)
    plt.xlabel("ITERATIONS")
    plt.ylabel("LOSS")
    plt.show()

# %%
class CustomDataset(Dataset):
    
    def __init__(self,image_folders,transform=None,should_invert=True):
        self.image_folders = image_folders    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.image_folders.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.image_folders.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                
                img1_tuple = random.choice(self.image_folders.imgs) 
                if img0_tuple[1] !=img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.image_folders.imgs)

# %%
#Defining the paths for training and testing data
training_dir = "/content/drive/My Drive/Siamse/Siamese/data/faces/training/"
testing_dir = "/content/drive/My Drive/Siamse/Siamese/data/faces/testing/"

folder_dataset = dset.ImageFolder(root = training_dir)

# %%
transform = transforms.Compose([transforms.Resize((100,100)) , transforms.ToTensor()])

dataset = CustomDataset(image_folders = folder_dataset , transform = transform , should_invert = False)
v_loader = DataLoader(dataset , shuffle = True ,batch_size = 8)
print(len(v_loader))
# Out:
# 47

# %%
#Visualizing some of the data

v_loader = DataLoader(dataset , shuffle = True ,batch_size = 8)
data_iter = iter(v_loader)
ex_batch = next(data_iter)
cc = torch.cat((ex_batch[0] , ex_batch[1]) , 0)
image_show(vutils.make_grid(cc))

# %%
#Declaring variable to check whether gpu is available or not
use_cuda = torch.cuda.is_available()
if use_cuda:
    print("Using GPU")
else:
    print("Using CPU")
# Out:
# Using GPU

# %%
#Describing the architecture of the convolutional net

class Siamese_net(nn.Module):
    
    def __init__(self):
        super(Siamese_net , self).__init__()
        
        self.conv_layers = nn.Sequential(
                                nn.ReplicationPad2d(1),
                                nn.Conv2d(1,4 , kernel_size = 3),
                                nn.ReLU(inplace = True),
                                nn.BatchNorm2d(4),
                                
                                nn.ReplicationPad2d(1),
                                nn.Conv2d(4,8 , kernel_size = 3),
                                nn.ReLU(inplace = True),
                                nn.BatchNorm2d(8),
        
                                nn.ReplicationPad2d(1),
                                nn.Conv2d(8,8 , kernel_size = 3),
                                nn.ReLU(inplace = True),
                                nn.BatchNorm2d(8))
        
        self.fully_connect = nn.Sequential(nn.Linear(8*100*100 , 500),
                                           nn.ReLU(inplace = True),
                                           nn.Linear(500,500),
                                           nn.ReLU(inplace = True),
                                           nn.Linear(500 , 5))
    
    def forward_once(self , x):
        output = self.conv_layers(x)
        output = output.view(output.size()[0], -1)
        output = self.fully_connect(output)
        return output
    
    def forward(self , inp1 , inp2):
        
        op1 = self.forward_once(inp1)
        op2 = self.forward_once(inp2)
        
        return op1 , op2

# %% [markdown]
# # Contrastive Loss
#
# ![title](https://cdn-images-1.medium.com/max/1000/1*tDo6545MUvW9t-A8Sd-hHw.png)
#
# #### Dw : euclidean distance
#
#
# #### Gw : output of sister pair networks
#
#
# #### m : margin value which is greater than 0.Having a margin indicates that dissimilar pairs that are beyond this margin will not contribute to the loss.

# %%
#Defining the loss

class Contrastive_loss(torch.nn.Module):
    
    '''Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf'''
    def __init__(self, margin=2.0):
        super(Contrastive_loss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %%
#Defining the batch_size and epochs

batch_size = 64 
num_epochs = 200

#Defning the data loader

train_loader = DataLoader(dataset , batch_size = batch_size , shuffle = True)

# %%
#Defining the loss and optimizer
net = Siamese_net()
if use_cuda:
    net = net.cuda()
    print(net)
criterion = Contrastive_loss()
optimizer = optim.Adam(net.parameters() , lr = 0.0005)
# Out:
# Siamese_net(
#   (conv_layers): Sequential(
#     (0): ReplicationPad2d((1, 1, 1, 1))
#     (1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1))
#     (2): ReLU(inplace)
#     (3): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReplicationPad2d((1, 1, 1, 1))
#     (5): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1))
#     (6): ReLU(inplace)
#     (7): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReplicationPad2d((1, 1, 1, 1))
#     (9): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1))
#     (10): ReLU(inplace)
#     (11): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fully_connect): Sequential(
#     (0): Linear(in_features=80000, out_features=500, bias=True)
#     (1): ReLU(inplace)
#     (2): Linear(in_features=500, out_features=500, bias=True)
#     (3): ReLU(inplace)
#     (4): Linear(in_features=500, out_features=5, bias=True)
#   )
# )

# %%
iteration_num = 0
counter = []
loss_history = []

# %%
#Training time

for epoch in range(num_epochs):
    
    for i , data in enumerate(train_loader , 0):
        
        img0 , img1 , label = data
        if use_cuda:
            img0 , img1 , label = img0.cuda() , img1.cuda() , label.cuda()
        optimizer.zero_grad()
        op1 , op2 = net(img0 , img1)
        loss = criterion(op1 , op2 , label)
        loss.backward()
        optimizer.step()
        
        if i%10 == 0:
            print("Epoch : {} || Contrastive Loss : {}".format(epoch , loss.item()))
            iteration_num += 10
            counter.append(iteration_num)
            loss_history.append(loss.item())
# Out:
# Epoch : 0 || Contrastive Loss : 2.0894768238067627
# Epoch : 1 || Contrastive Loss : 3.629091501235962
# Epoch : 2 || Contrastive Loss : 1.7814072370529175
# Epoch : 3 || Contrastive Loss : 0.8390343189239502
# Epoch : 4 || Contrastive Loss : 0.4215201437473297
# Epoch : 5 || Contrastive Loss : 0.5594664216041565
# Epoch : 6 || Contrastive Loss : 0.3154034912586212
# Epoch : 7 || Contrastive Loss : 0.3159298896789551
# Epoch : 8 || Contrastive Loss : 0.26188406348228455
# Epoch : 9 || Contrastive Loss : 0.1919102668762207
# Epoch : 10 || Contrastive Loss : 0.1897483766078949
# Epoch : 11 || Contrastive Loss : 0.17164845764636993
# Epoch : 12 || Contrastive Loss : 0.14992858469486237
# Epoch : 13 || Contrastive Loss : 0.11551110446453094
# Epoch : 14 || Contrastive Loss : 0.11156581342220306
# Epoch : 15 || Contrastive Loss : 0.08889099955558777
# Epoch : 16 || Contrastive Loss : 0.10390999168157578
# Epoch : 17 || Contrastive Loss : 0.10485271364450455
# Epoch : 18 || Contrastive Loss : 0.06447625905275345
# Epoch : 19 || Contrastive Loss : 0.09689698368310928
# Epoch : 20 || Contrastive Loss : 0.07091141492128372
# Epoch : 21 || Contrastive Loss : 0.07209086418151855
# Epoch : 22 || Contrastive Loss : 0.04204247519373894
# Epoch : 23 || Contrastive Loss : 0.09493628144264221
# Epoch : 24 || Contrastive Loss : 0.08114947378635406
# Epoch : 25 || Contrastive Loss : 0.07189799845218658
# Epoch : 26 || Contrastive Loss : 0.03259763494133949
# Epoch : 27 || Contrastive Loss : 0.037393081933259964
# Epoch : 28 || Contrastive Loss : 0.06039940565824509
# Epoch : 29 || Contrastive Loss : 0.03560735285282135
# Epoch : 30 || Contrastive Loss : 0.024675317108631134
# Epoch : 31 || Contrastive Loss : 0.034559354186058044
# Epoch : 32 || Contrastive Loss : 0.0421825647354126
# Epoch : 33 || Contrastive Loss : 0.049033503979444504
# Epoch : 34 || Contrastive Loss : 0.03144986927509308
# Epoch : 35 || Contrastive Loss : 0.03303419426083565
# Epoch : 36 || Contrastive Loss : 0.041764214634895325
# Epoch : 37 || Contrastive Loss : 0.03724519908428192
# Epoch : 38 || Contrastive Loss : 0.029368795454502106
# Epoch : 39 || Contrastive Loss : 0.041419390588998795
# Epoch : 40 || Contrastive Loss : 0.027791855856776237
# Epoch : 41 || Contrastive Loss : 0.03372529149055481
# Epoch : 42 || Contrastive Loss : 0.031372278928756714
# Epoch : 43 || Contrastive Loss : 0.0176350437104702
# Epoch : 44 || Contrastive Loss : 0.021308809518814087
# Epoch : 45 || Contrastive Loss : 0.022519433870911598
# Epoch : 46 || Contrastive Loss : 0.02244126982986927
# Epoch : 47 || Contrastive Loss : 0.016276171430945396
# Epoch : 48 || Contrastive Loss : 0.021395482122898102
# Epoch : 49 || Contrastive Loss : 0.014517981559038162
# Epoch : 50 || Contrastive Loss : 0.019057895988225937
# Epoch : 51 || Contrastive Loss : 0.012290311977267265
# Epoch : 52 || Contrastive Loss : 0.029252156615257263
# Epoch : 53 || Contrastive Loss : 0.015784449875354767
# Epoch : 54 || Contrastive Loss : 0.018945911899209023
# Epoch : 55 || Contrastive Loss : 0.023119941353797913
# Epoch : 56 || Contrastive Loss : 0.011793437413871288
# Epoch : 57 || Contrastive Loss : 0.023547053337097168
# Epoch : 58 || Contrastive Loss : 0.017197463661432266
# Epoch : 59 || Contrastive Loss : 0.023270851001143456
# Epoch : 60 || Contrastive Loss : 0.011616954579949379
# Epoch : 61 || Contrastive Loss : 0.014928551390767097
# Epoch : 62 || Contrastive Loss : 0.02959863841533661
# Epoch : 63 || Contrastive Loss : 0.02152666449546814
# Epoch : 64 || Contrastive Loss : 0.012844346463680267
# Epoch : 65 || Contrastive Loss : 0.010790020227432251
# Epoch : 66 || Contrastive Loss : 0.022753173485398293
# Epoch : 67 || Contrastive Loss : 0.012272310443222523
# Epoch : 68 || Contrastive Loss : 0.010089907795190811
# Epoch : 69 || Contrastive Loss : 0.02387651428580284
# Epoch : 70 || Contrastive Loss : 0.011603234335780144
# Epoch : 71 || Contrastive Loss : 0.018408071249723434
# Epoch : 72 || Contrastive Loss : 0.013810742646455765
# Epoch : 73 || Contrastive Loss : 0.007736928761005402
# Epoch : 74 || Contrastive Loss : 0.00998000055551529
# Epoch : 75 || Contrastive Loss : 0.015437418594956398
# Epoch : 76 || Contrastive Loss : 0.010046357288956642
# Epoch : 77 || Contrastive Loss : 0.009519126266241074
# Epoch : 78 || Contrastive Loss : 0.011017898097634315
# Epoch : 79 || Contrastive Loss : 0.011655639857053757
# Epoch : 80 || Contrastive Loss : 0.010815689340233803
# Epoch : 81 || Contrastive Loss : 0.01797940582036972
# Epoch : 82 || Contrastive Loss : 0.015962250530719757
# Epoch : 83 || Contrastive Loss : 0.012436715885996819
# Epoch : 84 || Contrastive Loss : 0.010064482688903809
# Epoch : 85 || Contrastive Loss : 0.01258043758571148
# Epoch : 86 || Contrastive Loss : 0.010423967614769936
# Epoch : 87 || Contrastive Loss : 0.013923252001404762
# Epoch : 88 || Contrastive Loss : 0.009281903505325317
# Epoch : 89 || Contrastive Loss : 0.012580379843711853
# Epoch : 90 || Contrastive Loss : 0.02093188464641571
# Epoch : 91 || Contrastive Loss : 0.010042145848274231
# Epoch : 92 || Contrastive Loss : 0.014806585386395454
# Epoch : 93 || Contrastive Loss : 0.010478358715772629
# Epoch : 94 || Contrastive Loss : 0.01338026113808155
# Epoch : 95 || Contrastive Loss : 0.015143440105021
# Epoch : 96 || Contrastive Loss : 0.0058256094343960285
# Epoch : 97 || Contrastive Loss : 0.013647707179188728
# Epoch : 98 || Contrastive Loss : 0.012920397333800793
# Epoch : 99 || Contrastive Loss : 0.008722629398107529
# Epoch : 100 || Contrastive Loss : 0.01217072643339634
# Epoch : 101 || Contrastive Loss : 0.008992742747068405
# Epoch : 102 || Contrastive Loss : 0.010652787983417511
# Epoch : 103 || Contrastive Loss : 0.007627319078892469
# Epoch : 104 || Contrastive Loss : 0.007931792177259922
# Epoch : 105 || Contrastive Loss : 0.0087382011115551
# Epoch : 106 || Contrastive Loss : 0.005228196270763874
# Epoch : 107 || Contrastive Loss : 0.008328059688210487
# Epoch : 108 || Contrastive Loss : 0.008024297654628754
# Epoch : 109 || Contrastive Loss : 0.005989483091980219
# Epoch : 110 || Contrastive Loss : 0.009743615984916687
# Epoch : 111 || Contrastive Loss : 0.006957747973501682
# Epoch : 112 || Contrastive Loss : 0.004569462966173887
# Epoch : 113 || Contrastive Loss : 0.007907778955996037
# Epoch : 114 || Contrastive Loss : 0.0068872421979904175
# Epoch : 115 || Contrastive Loss : 0.0063993255607783794
# Epoch : 116 || Contrastive Loss : 0.005905818194150925
# Epoch : 117 || Contrastive Loss : 0.007508446462452412
# Epoch : 118 || Contrastive Loss : 0.0055819363333284855
# Epoch : 119 || Contrastive Loss : 0.006738519761711359
# Epoch : 120 || Contrastive Loss : 0.0070770736783742905
# Epoch : 121 || Contrastive Loss : 0.007001836784183979
# Epoch : 122 || Contrastive Loss : 0.004929293412715197
# Epoch : 123 || Contrastive Loss : 0.004213237203657627
# Epoch : 124 || Contrastive Loss : 0.004451865330338478
# Epoch : 125 || Contrastive Loss : 0.00485443789511919
# Epoch : 126 || Contrastive Loss : 0.004466325044631958
# Epoch : 127 || Contrastive Loss : 0.0051355380564928055
# Epoch : 128 || Contrastive Loss : 0.002583186374977231
# Epoch : 129 || Contrastive Loss : 0.004449260421097279
# Epoch : 130 || Contrastive Loss : 0.004170549567788839
# Epoch : 131 || Contrastive Loss : 0.00571861770004034
# Epoch : 132 || Contrastive Loss : 0.00598030723631382
# Epoch : 133 || Contrastive Loss : 0.007307914085686207
# Epoch : 134 || Contrastive Loss : 0.0064448402263224125
# Epoch : 135 || Contrastive Loss : 0.0034603227395564318
# Epoch : 136 || Contrastive Loss : 0.0036449239123612642
# Epoch : 137 || Contrastive Loss : 0.005448140203952789
# Epoch : 138 || Contrastive Loss : 0.008519627153873444
# Epoch : 139 || Contrastive Loss : 0.008172336034476757
# Epoch : 140 || Contrastive Loss : 0.004356623161584139
# Epoch : 141 || Contrastive Loss : 0.007441574241966009
# Epoch : 142 || Contrastive Loss : 0.007645915262401104
# Epoch : 143 || Contrastive Loss : 0.00714018102735281
# Epoch : 144 || Contrastive Loss : 0.00510662654414773
# Epoch : 145 || Contrastive Loss : 0.0034675896167755127
# Epoch : 146 || Contrastive Loss : 0.008143328130245209
# Epoch : 147 || Contrastive Loss : 0.00815332867205143
# Epoch : 148 || Contrastive Loss : 0.0036374819464981556
# Epoch : 149 || Contrastive Loss : 0.007452712394297123
# Epoch : 150 || Contrastive Loss : 0.006188090890645981
# Epoch : 151 || Contrastive Loss : 0.00712495855987072
# Epoch : 152 || Contrastive Loss : 0.007206421345472336
# Epoch : 153 || Contrastive Loss : 0.0035173618234694004
# Epoch : 154 || Contrastive Loss : 0.004083613865077496
# Epoch : 155 || Contrastive Loss : 0.005769097246229649
# Epoch : 156 || Contrastive Loss : 0.003915830980986357
# Epoch : 157 || Contrastive Loss : 0.007669233251363039
# Epoch : 158 || Contrastive Loss : 0.006123077590018511
# Epoch : 159 || Contrastive Loss : 0.007331267464905977
# Epoch : 160 || Contrastive Loss : 0.006562720984220505
# Epoch : 161 || Contrastive Loss : 0.004855828359723091
# Epoch : 162 || Contrastive Loss : 0.008518343791365623
# Epoch : 163 || Contrastive Loss : 0.007198325823992491
# Epoch : 164 || Contrastive Loss : 0.01676023192703724
# Epoch : 165 || Contrastive Loss : 0.005625604651868343
# Epoch : 166 || Contrastive Loss : 0.007875701412558556
# Epoch : 167 || Contrastive Loss : 0.00696991290897131
# Epoch : 168 || Contrastive Loss : 0.006850793492048979
# Epoch : 169 || Contrastive Loss : 0.0058257365599274635
# Epoch : 170 || Contrastive Loss : 0.00634818896651268
# Epoch : 171 || Contrastive Loss : 0.006403700448572636
# Epoch : 172 || Contrastive Loss : 0.004146873019635677
# Epoch : 173 || Contrastive Loss : 0.007068302948027849
# Epoch : 174 || Contrastive Loss : 0.006731538102030754
# Epoch : 175 || Contrastive Loss : 0.003339579328894615
# Epoch : 176 || Contrastive Loss : 0.007939552888274193
# Epoch : 177 || Contrastive Loss : 0.004466122016310692
# Epoch : 178 || Contrastive Loss : 0.012569408863782883
# Epoch : 179 || Contrastive Loss : 0.008685425855219364
# Epoch : 180 || Contrastive Loss : 0.0077733867801725864
# Epoch : 181 || Contrastive Loss : 0.007391438353806734
# Epoch : 182 || Contrastive Loss : 0.009279366582632065
# Epoch : 183 || Contrastive Loss : 0.006845356896519661
# Epoch : 184 || Contrastive Loss : 0.00625188322737813
# Epoch : 185 || Contrastive Loss : 0.004846246913075447
# Epoch : 186 || Contrastive Loss : 0.0051832497119903564
# Epoch : 187 || Contrastive Loss : 0.006340177729725838
# Epoch : 188 || Contrastive Loss : 0.004890339449048042
# Epoch : 189 || Contrastive Loss : 0.007625045254826546
# Epoch : 190 || Contrastive Loss : 0.005418021231889725
# Epoch : 191 || Contrastive Loss : 0.00485216174274683
# Epoch : 192 || Contrastive Loss : 0.0044871000573039055
# Epoch : 193 || Contrastive Loss : 0.004154995083808899
# Epoch : 194 || Contrastive Loss : 0.005875185132026672
# Epoch : 195 || Contrastive Loss : 0.005231974180787802
# Epoch : 196 || Contrastive Loss : 0.005922217853367329
# Epoch : 197 || Contrastive Loss : 0.004573209676891565
# Epoch : 198 || Contrastive Loss : 0.0049593341536819935
# Epoch : 199 || Contrastive Loss : 0.00483158603310585

# %%
plot_loss(counter , loss_history)

# %%
#Time for testing
test_data_folder = dset.ImageFolder(root = testing_dir)

transform = transforms.Compose([transforms.Resize((100,100)) , transforms.ToTensor()])

test_dataset = CustomDataset(test_data_folder , transform  = transform, should_invert = False)

test_loader = DataLoader(test_dataset , batch_size = 1 , shuffle  = True)

# %%
dataiter = iter(test_loader)
x0 , _ ,_ = next(dataiter)

for i in range(15):
    
    _, x1 , label = next(dataiter)
    cc = torch.cat((x0,x1) , 0)
    op1 , op2 = net(Variable(x0).cuda() , Variable(x1).cuda())
    eu_dist = F.pairwise_distance(op1 , op2)
    image_show(vutils.make_grid(cc) , 'Dissimilarity Score : {:2f}'.format(eu_dist.item()))
